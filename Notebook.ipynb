# %%
# Install contraint library
# %pip install python-constraint
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import contraint library
from constraint import *

# %%
# Introdução
# O problema de Class Timetabling consiste em atribuir aulas a horários e salas, respeitando restrições como disponibilidade de professores, salas e evitando conflitos de horários.
# O ficheiro ClassTT_01_tiny.txt contém uma versão reduzida deste problema, com dados sobre aulas, professores, salas e horários.

# Design do Agente
# O agente será responsável por encontrar uma solução viável para o problema de horário,
# O agente irá:
# 1. Ler os dados do ficheiro ClassTT_01_tiny.txt.
# 2. Definir variáveis para cada aula (por exemplo, aula1, aula2, ...).
# 3. Definir o domínio de cada variável (possíveis combinações de sala e horário).
# 4. Adicionar restrições para evitar conflitos (por exemplo, um professor não pode dar duas aulas ao mesmo tempo, uma sala não pode ser ocupada por duas aulas simultaneamente).
# 5. Encontrar soluções que satisfaçam todas as restrições.

# Exemplo de leitura do ficheiro e preparação dos dados:
with open('ClassTT_01_tiny.txt', 'r') as f:
    lines = f.readlines()
    for line in lines:
        print(line.strip())
# Out:
# #head
# â€” All classes last 2 hours
# â€” Classes will be schedule from Monday to Friday
# â€” Each day has 4 blocks of 2 hour each
# â€” Blocks are numbered from 1 to 20 (5 days *4 blocks), Monday 9am to Friday 4pm
# â€” In this dataset alll classes have 2 lessons per week
#
# #cc â€” courses assigned to classes (class, courses*)
# t01         UC11 UC12 UC13 UC14 UC15
# t02         UC21 UC22 UC23 UC24 UC25
# t03         UC31 UC32 UC33 UC34 UC35
#
# #olw â€” courses with just one lesson per week
#
# #dsd â€” courses assigned to lecturers (teacher, courses*)
# jo          UC11 UC21 UC22 UC31
# mike     UC12 UC23 UC32
# rob        UC13 UC14 UC24 UC33
# sue       UC15 UC25 UC34 UC35
#
# #tr â€” timeslot  restrictions (teacher, slots_unavailable*)
# mike   13 14 15 16 17 18 19 20
# rob      1 2 3 4
# sue      9 10 11 12 17 18 19 20
#
# #rr â€” room  restrictions (course, room)
# UC14   Lab01
# UC22   Lab01
#
# #oc â€” online classes (course, lesson_week_index)
# UC21   2
# UC31   2
